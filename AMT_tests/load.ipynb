# %%
import os

def get_file_list(audio_folder, text_folder):
    """
    This function gets the base file names that are present in both the audio and text folders.

    Args:
    - audio_folder: Path to the folder containing the audio files.
    - text_folder: Path to the folder containing the text files.

    Returns:
    - A list of base file names (without extensions) that are present in both folders.
    """
    # Get the set of audio files (without extensions)
    audio_files = set(os.path.splitext(f)[0] for f in os.listdir(audio_folder) if f.endswith('.wav'))

    # Get the set of text files (without extensions)
    text_files = set(os.path.splitext(f)[0] for f in os.listdir(text_folder) if f.endswith('.txt'))

    # Find the intersection of both sets (i.e., files present in both folders)
    common_files = list(audio_files.intersection(text_files))

    return sorted(common_files)

# %%
# Example usage
audio_folder = '/root/dev/data/audio'
text_folder = '/root/dev/data/text'
file_list = get_file_list(audio_folder, text_folder)

print(f"Found {len(file_list)} matching files.")
for file in file_list:
    print(file)
# Out:
# Found 270 matching files.
# MAPS_MUS-alb_esp2_AkPnCGdD
# MAPS_MUS-alb_esp2_AkPnStgb
# MAPS_MUS-alb_esp2_SptkBGAm
# MAPS_MUS-alb_esp2_SptkBGCl
# MAPS_MUS-alb_esp3_AkPnCGdD
# MAPS_MUS-alb_esp4_AkPnStgb
# MAPS_MUS-alb_esp5_SptkBGCl
# MAPS_MUS-alb_esp6_SptkBGCl
# MAPS_MUS-alb_se2_ENSTDkCl
# MAPS_MUS-alb_se2_StbgTGd2
# MAPS_MUS-alb_se3_AkPnBcht
# MAPS_MUS-alb_se3_AkPnBsdf
# MAPS_MUS-alb_se4_AkPnBsdf
# MAPS_MUS-alb_se6_AkPnStgb
# MAPS_MUS-alb_se7_AkPnBsdf
# MAPS_MUS-alb_se8_SptkBGAm
# MAPS_MUS-appass_1_AkPnBsdf
# MAPS_MUS-appass_1_SptkBGCl
# MAPS_MUS-appass_3_AkPnStgb
# MAPS_MUS-bach_846_AkPnBcht
# MAPS_MUS-bach_846_SptkBGAm
# MAPS_MUS-bach_847_AkPnBcht
# MAPS_MUS-bach_847_AkPnStgb
# MAPS_MUS-bach_847_SptkBGCl
# MAPS_MUS-bach_850_AkPnBsdf
# MAPS_MUS-bk_xmas1_AkPnBsdf
# MAPS_MUS-bk_xmas1_AkPnStgb
# MAPS_MUS-bk_xmas1_ENSTDkAm
# MAPS_MUS-bk_xmas1_ENSTDkCl
# MAPS_MUS-bk_xmas1_StbgTGd2
# MAPS_MUS-bk_xmas2_AkPnStgb
# MAPS_MUS-bk_xmas2_SptkBGCl
# MAPS_MUS-bk_xmas3_AkPnStgb
# MAPS_MUS-bk_xmas4_ENSTDkCl
# MAPS_MUS-bk_xmas4_SptkBGCl
# MAPS_MUS-bk_xmas4_StbgTGd2
# MAPS_MUS-bk_xmas5_AkPnBcht
# MAPS_MUS-bk_xmas5_AkPnCGdD
# MAPS_MUS-bk_xmas5_ENSTDkCl
# MAPS_MUS-bk_xmas5_StbgTGd2
# MAPS_MUS-bor_ps1_AkPnCGdD
# MAPS_MUS-bor_ps2_SptkBGAm
# MAPS_MUS-bor_ps5_AkPnStgb
# MAPS_MUS-bor_ps6_AkPnBsdf
# MAPS_MUS-bor_ps6_ENSTDkCl
# MAPS_MUS-bor_ps6_StbgTGd2
# MAPS_MUS-br_im2_AkPnCGdD
# MAPS_MUS-br_im2_SptkBGAm
# MAPS_MUS-br_im5_AkPnBsdf
# MAPS_MUS-br_im5_AkPnCGdD
# MAPS_MUS-br_im5_SptkBGCl
# MAPS_MUS-br_im6_AkPnStgb
# MAPS_MUS-burg_perlen_SptkBGCl
# MAPS_MUS-burg_quelle_SptkBGAm
# MAPS_MUS-chp_op18_AkPnCGdD
# MAPS_MUS-chp_op31_AkPnBcht
# MAPS_MUS-chp_op31_AkPnStgb
# MAPS_MUS-chpn-e01_ENSTDkCl
# MAPS_MUS-chpn-e01_SptkBGAm
# MAPS_MUS-chpn-e01_StbgTGd2
# MAPS_MUS-chpn-p10_AkPnStgb
# MAPS_MUS-chpn-p11-format0_AkPnCGdD
# MAPS_MUS-chpn-p11_AkPnCGdD
# MAPS_MUS-chpn-p12_AkPnBcht
# MAPS_MUS-chpn-p13_AkPnBcht
# MAPS_MUS-chpn-p13_AkPnCGdD
# MAPS_MUS-chpn-p14_AkPnBcht
# MAPS_MUS-chpn-p14_AkPnCGdD
# MAPS_MUS-chpn-p14_ENSTDkAm
# MAPS_MUS-chpn-p15_AkPnCGdD
# MAPS_MUS-chpn-p15_ENSTDkAm
# MAPS_MUS-chpn-p16_AkPnStgb
# MAPS_MUS-chpn-p19_AkPnBsdf
# MAPS_MUS-chpn-p19_ENSTDkCl
# MAPS_MUS-chpn-p19_StbgTGd2
# MAPS_MUS-chpn-p1_AkPnBcht
# MAPS_MUS-chpn-p1_AkPnBsdf
# MAPS_MUS-chpn-p20_AkPnCGdD
# MAPS_MUS-chpn-p21_AkPnBsdf
# MAPS_MUS-chpn-p24_AkPnBcht
# MAPS_MUS-chpn-p2_SptkBGCl
# MAPS_MUS-chpn-p3_AkPnBcht
# MAPS_MUS-chpn-p4_AkPnBcht
# MAPS_MUS-chpn-p4_AkPnBsdf
# MAPS_MUS-chpn-p4_ENSTDkAm
# MAPS_MUS-chpn-p6_SptkBGAm
# MAPS_MUS-chpn-p6_SptkBGCl
# MAPS_MUS-chpn-p7_AkPnCGdD
# MAPS_MUS-chpn-p7_SptkBGCl
# MAPS_MUS-chpn-p8_AkPnBcht
# MAPS_MUS-chpn-p9_AkPnBsdf
# MAPS_MUS-chpn_op10_e01_AkPnCGdD
# MAPS_MUS-chpn_op10_e05_SptkBGAm
# MAPS_MUS-chpn_op10_e12_AkPnCGdD
# MAPS_MUS-chpn_op25_e2_AkPnBcht
# MAPS_MUS-chpn_op25_e3_ENSTDkAm
# MAPS_MUS-chpn_op25_e3_SptkBGAm
# MAPS_MUS-chpn_op25_e4_ENSTDkAm
# MAPS_MUS-chpn_op27_1_AkPnCGdD
# MAPS_MUS-chpn_op27_2_AkPnStgb
# MAPS_MUS-chpn_op27_2_SptkBGCl
# MAPS_MUS-chpn_op33_2_ENSTDkAm
# MAPS_MUS-chpn_op33_2_SptkBGAm
# MAPS_MUS-chpn_op33_4_SptkBGAm
# MAPS_MUS-chpn_op35_1_ENSTDkAm
# MAPS_MUS-chpn_op35_3_AkPnStgb
# MAPS_MUS-chpn_op66_AkPnBcht
# MAPS_MUS-chpn_op66_ENSTDkAm
# MAPS_MUS-chpn_op7_1_ENSTDkAm
# MAPS_MUS-chpn_op7_2_SptkBGAm
# MAPS_MUS-deb_clai_ENSTDkCl
# MAPS_MUS-deb_clai_StbgTGd2
# MAPS_MUS-deb_menu_ENSTDkCl
# MAPS_MUS-deb_menu_StbgTGd2
# MAPS_MUS-deb_pass_SptkBGAm
# MAPS_MUS-gra_esp_2_AkPnStgb
# MAPS_MUS-gra_esp_3_SptkBGAm
# MAPS_MUS-gra_esp_3_SptkBGCl
# MAPS_MUS-gra_esp_4_AkPnBcht
# MAPS_MUS-grieg_butterfly_AkPnBsdf
# MAPS_MUS-grieg_butterfly_ENSTDkAm
# MAPS_MUS-grieg_butterfly_ENSTDkCl
# MAPS_MUS-grieg_butterfly_StbgTGd2
# MAPS_MUS-grieg_elfentanz_AkPnBsdf
# MAPS_MUS-grieg_elfentanz_SptkBGAm
# MAPS_MUS-grieg_halling_AkPnBsdf
# MAPS_MUS-grieg_kobold_AkPnCGdD
# MAPS_MUS-grieg_kobold_AkPnStgb
# MAPS_MUS-grieg_kobold_ENSTDkAm
# MAPS_MUS-grieg_waechter_AkPnBcht
# MAPS_MUS-grieg_walzer_AkPnBcht
# MAPS_MUS-grieg_walzer_SptkBGCl
# MAPS_MUS-grieg_wanderer_AkPnBsdf
# MAPS_MUS-grieg_wanderer_SptkBGAm
# MAPS_MUS-grieg_zwerge_AkPnBcht
# MAPS_MUS-hay_40_1_AkPnBcht
# MAPS_MUS-liz_et1_SptkBGAm
# MAPS_MUS-liz_et2_AkPnStgb
# MAPS_MUS-liz_et2_SptkBGAm
# MAPS_MUS-liz_et3_AkPnStgb
# MAPS_MUS-liz_et4_SptkBGCl
# MAPS_MUS-liz_et5_AkPnCGdD
# MAPS_MUS-liz_et6_AkPnBsdf
# MAPS_MUS-liz_et6_AkPnCGdD
# MAPS_MUS-liz_et6_ENSTDkCl
# MAPS_MUS-liz_et6_StbgTGd2
# MAPS_MUS-liz_et_trans4_SptkBGAm
# MAPS_MUS-liz_et_trans5_AkPnCGdD
# MAPS_MUS-liz_et_trans5_ENSTDkCl
# MAPS_MUS-liz_et_trans5_StbgTGd2
# MAPS_MUS-liz_rhap02_AkPnCGdD
# MAPS_MUS-liz_rhap02_ENSTDkAm
# MAPS_MUS-liz_rhap09_ENSTDkAm
# MAPS_MUS-liz_rhap09_ENSTDkCl
# MAPS_MUS-liz_rhap09_SptkBGCl
# MAPS_MUS-liz_rhap09_StbgTGd2
# MAPS_MUS-liz_rhap10_AkPnBsdf
# MAPS_MUS-liz_rhap12_ENSTDkAm
# MAPS_MUS-mendel_op53_5_AkPnCGdD
# MAPS_MUS-mendel_op62_5_ENSTDkAm
# MAPS_MUS-mendel_op62_5_SptkBGAm
# MAPS_MUS-mond_1_AkPnBsdf
# MAPS_MUS-mond_1_SptkBGAm
# MAPS_MUS-mond_2_SptkBGAm
# MAPS_MUS-mond_2_SptkBGCl
# MAPS_MUS-mond_3_AkPnStgb
# MAPS_MUS-mos_op36_6_AkPnBsdf
# MAPS_MUS-muss_1_ENSTDkAm
# MAPS_MUS-muss_2_AkPnCGdD
# MAPS_MUS-muss_3_SptkBGCl
# MAPS_MUS-muss_4_AkPnBsdf
# MAPS_MUS-muss_5_AkPnBcht
# MAPS_MUS-mz_311_1_ENSTDkCl
# MAPS_MUS-mz_311_1_StbgTGd2
# MAPS_MUS-mz_330_1_SptkBGCl
# MAPS_MUS-mz_331_1_SptkBGCl
# MAPS_MUS-mz_331_2_AkPnBcht
# MAPS_MUS-mz_331_2_AkPnBsdf
# MAPS_MUS-mz_331_2_ENSTDkCl
# MAPS_MUS-mz_331_2_StbgTGd2
# MAPS_MUS-mz_331_3_AkPnBsdf
# MAPS_MUS-mz_331_3_ENSTDkCl
# MAPS_MUS-mz_331_3_StbgTGd2
# MAPS_MUS-mz_332_1_AkPnBsdf
# MAPS_MUS-mz_332_2_ENSTDkCl
# MAPS_MUS-mz_332_2_StbgTGd2
# MAPS_MUS-mz_333_1_AkPnStgb
# MAPS_MUS-mz_333_2_AkPnCGdD
# MAPS_MUS-mz_333_2_ENSTDkCl
# MAPS_MUS-mz_333_2_StbgTGd2
# MAPS_MUS-mz_333_3_ENSTDkCl
# MAPS_MUS-mz_333_3_StbgTGd2
# MAPS_MUS-mz_545_3_ENSTDkCl
# MAPS_MUS-mz_545_3_StbgTGd2
# MAPS_MUS-mz_570_1_ENSTDkCl
# MAPS_MUS-mz_570_1_StbgTGd2
# MAPS_MUS-pathetique_1_ENSTDkCl
# MAPS_MUS-pathetique_1_SptkBGCl
# MAPS_MUS-pathetique_1_StbgTGd2
# MAPS_MUS-pathetique_2_ENSTDkAm
# MAPS_MUS-pathetique_3_ENSTDkAm
# MAPS_MUS-schu_143_1_AkPnBcht
# MAPS_MUS-schu_143_1_ENSTDkAm
# MAPS_MUS-schu_143_2_AkPnCGdD
# MAPS_MUS-schu_143_3_ENSTDkCl
# MAPS_MUS-schu_143_3_StbgTGd2
# MAPS_MUS-schub_d760_1_AkPnBcht
# MAPS_MUS-schub_d760_3_ENSTDkAm
# MAPS_MUS-schub_d960_3_AkPnCGdD
# MAPS_MUS-schub_d960_3_AkPnStgb
# MAPS_MUS-schub_d960_3_SptkBGCl
# MAPS_MUS-schuim-1_AkPnStgb
# MAPS_MUS-schuim-1_ENSTDkCl
# MAPS_MUS-schuim-1_StbgTGd2
# MAPS_MUS-schuim-3_AkPnStgb
# MAPS_MUS-schumm-1_AkPnStgb
# MAPS_MUS-schumm-1_ENSTDkAm
# MAPS_MUS-schumm-2_SptkBGAm
# MAPS_MUS-schumm-3_AkPnStgb
# MAPS_MUS-schumm-6_AkPnBcht
# MAPS_MUS-scn15_11_ENSTDkAm
# MAPS_MUS-scn15_11_ENSTDkCl
# MAPS_MUS-scn15_11_StbgTGd2
# MAPS_MUS-scn15_12_ENSTDkCl
# MAPS_MUS-scn15_12_StbgTGd2
# MAPS_MUS-scn15_13_AkPnStgb
# MAPS_MUS-scn15_2_SptkBGCl
# MAPS_MUS-scn15_3_AkPnBcht
# MAPS_MUS-scn15_5_SptkBGCl
# MAPS_MUS-scn15_6_ENSTDkAm
# MAPS_MUS-scn15_7_AkPnBcht
# MAPS_MUS-scn15_7_SptkBGAm
# MAPS_MUS-scn15_9_ENSTDkAm
# MAPS_MUS-scn16_2_AkPnBcht
# MAPS_MUS-scn16_2_SptkBGCl
# MAPS_MUS-scn16_3_ENSTDkCl
# MAPS_MUS-scn16_3_StbgTGd2
# MAPS_MUS-scn16_4_AkPnBsdf
# MAPS_MUS-scn16_4_AkPnCGdD
# MAPS_MUS-scn16_4_ENSTDkAm
# MAPS_MUS-scn16_4_ENSTDkCl
# MAPS_MUS-scn16_4_SptkBGCl
# MAPS_MUS-scn16_4_StbgTGd2
# MAPS_MUS-scn16_5_SptkBGAm
# MAPS_MUS-scn16_7_SptkBGAm
# MAPS_MUS-ty_dezember_AkPnBsdf
# MAPS_MUS-ty_februar_AkPnCGdD
# MAPS_MUS-ty_februar_SptkBGCl
# MAPS_MUS-ty_januar_AkPnStgb
# MAPS_MUS-ty_juli_AkPnBcht
# MAPS_MUS-ty_juli_AkPnBsdf
# MAPS_MUS-ty_juni_AkPnBsdf
# MAPS_MUS-ty_maerz_ENSTDkAm
# MAPS_MUS-ty_maerz_ENSTDkCl
# MAPS_MUS-ty_maerz_StbgTGd2
# MAPS_MUS-ty_mai_AkPnBcht
# MAPS_MUS-ty_mai_ENSTDkAm
# MAPS_MUS-ty_mai_ENSTDkCl
# MAPS_MUS-ty_mai_SptkBGAm
# MAPS_MUS-ty_mai_StbgTGd2
# MAPS_MUS-ty_november_ENSTDkAm
# MAPS_MUS-ty_november_SptkBGCl
# MAPS_MUS-ty_oktober_SptkBGAm
# MAPS_MUS-ty_september_AkPnStgb
# MAPS_MUS-ty_september_SptkBGAm
# MAPS_MUS-waldstein_1_AkPnBsdf
# MAPS_MUS-waldstein_1_AkPnStgb
# MAPS_MUS-waldstein_1_ENSTDkAm
# MAPS_MUS-waldstein_2_AkPnCGdD
# MAPS_MUS-waldstein_3_SptkBGCl

# %%
import os

# Assuming your dataset is structured like this:
maps_files = file_list

# Extract the unique instruments and pieces
instruments = set()
pieces = set()

for file_name in maps_files:
    # Split by "-" to get the piece part
    piece_name = file_name.split('-')[1]  # The second element after splitting by "-"

    # Split by "_" and take the last element for the instrument name
    instrument_name = file_name.split('_')[-1]

    # Add to sets
    instruments.add(instrument_name)
    pieces.add(piece_name)

# Display the unique instruments and pieces
print(f"{len(instruments)}Unique Instruments (Categories for Training/Validation/Testing):")
for instrument in instruments:
    print(instrument)

print(f"\n{len(pieces)} Unique Pieces (Song Names):")
for piece in pieces:
    print(piece)
# Out:
# 9Unique Instruments (Categories for Training/Validation/Testing):
# ENSTDkCl
# StbgTGd2
# AkPnBcht
# AkPnBsdf
# AkPnStgb
# SptkBGAm
# ENSTDkAm
# SptkBGCl
# AkPnCGdD
#
# 230 Unique Pieces (Song Names):
# deb_pass_SptkBGAm
# muss_2_AkPnCGdD
# mendel_op62_5_SptkBGAm
# schu_143_2_AkPnCGdD
# grieg_halling_AkPnBsdf
# bk_xmas1_ENSTDkAm
# gra_esp_3_SptkBGCl
# schu_143_3_StbgTGd2
# ty_mai_SptkBGAm
# chp_op18_AkPnCGdD
# scn16_5_SptkBGAm
# alb_esp2_SptkBGAm
# grieg_zwerge_AkPnBcht
# mz_333_3_ENSTDkCl
# scn15_7_SptkBGAm
# bk_xmas2_AkPnStgb
# mz_333_2_AkPnCGdD
# mz_333_3_StbgTGd2
# scn16_4_AkPnBsdf
# waldstein_1_AkPnStgb
# chpn
# liz_et6_ENSTDkCl
# mos_op36_6_AkPnBsdf
# liz_et6_StbgTGd2
# pathetique_1_StbgTGd2
# ty_mai_ENSTDkAm
# bor_ps6_ENSTDkCl
# scn16_4_AkPnCGdD
# bk_xmas5_ENSTDkCl
# mz_545_3_StbgTGd2
# chp_op31_AkPnBcht
# br_im5_AkPnCGdD
# liz_et3_AkPnStgb
# scn15_5_SptkBGCl
# scn15_11_ENSTDkAm
# ty_mai_AkPnBcht
# mz_333_2_StbgTGd2
# scn15_9_ENSTDkAm
# scn16_7_SptkBGAm
# chpn_op33_2_SptkBGAm
# bor_ps5_AkPnStgb
# chpn_op27_2_SptkBGCl
# scn16_4_ENSTDkCl
# scn15_11_StbgTGd2
# gra_esp_2_AkPnStgb
# liz_et6_AkPnCGdD
# mz_332_2_StbgTGd2
# ty_maerz_ENSTDkAm
# scn15_7_AkPnBcht
# mz_332_2_ENSTDkCl
# br_im5_AkPnBsdf
# grieg_kobold_ENSTDkAm
# chpn_op27_2_AkPnStgb
# ty_februar_AkPnCGdD
# appass_3_AkPnStgb
# chpn_op27_1_AkPnCGdD
# chpn_op25_e3_SptkBGAm
# bk_xmas4_SptkBGCl
# bk_xmas1_AkPnStgb
# liz_et_trans5_StbgTGd2
# chp_op31_AkPnStgb
# mendel_op53_5_AkPnCGdD
# bk_xmas2_SptkBGCl
# muss_4_AkPnBsdf
# br_im6_AkPnStgb
# liz_et6_AkPnBsdf
# scn16_2_AkPnBcht
# scn16_3_ENSTDkCl
# bk_xmas4_ENSTDkCl
# chpn_op10_e12_AkPnCGdD
# ty_dezember_AkPnBsdf
# mz_570_1_StbgTGd2
# scn15_11_ENSTDkCl
# mz_331_3_StbgTGd2
# mz_333_1_AkPnStgb
# mz_330_1_SptkBGCl
# waldstein_1_ENSTDkAm
# ty_september_AkPnStgb
# mond_2_SptkBGAm
# ty_juli_AkPnBsdf
# liz_rhap10_AkPnBsdf
# muss_1_ENSTDkAm
# bor_ps6_StbgTGd2
# mz_311_1_ENSTDkCl
# pathetique_3_ENSTDkAm
# scn15_13_AkPnStgb
# mz_545_3_ENSTDkCl
# bor_ps1_AkPnCGdD
# alb_se8_SptkBGAm
# alb_se7_AkPnBsdf
# grieg_kobold_AkPnCGdD
# liz_et_trans5_AkPnCGdD
# mz_331_3_AkPnBsdf
# bk_xmas4_StbgTGd2
# chpn_op66_ENSTDkAm
# grieg_elfentanz_AkPnBsdf
# chpn_op25_e3_ENSTDkAm
# liz_rhap02_ENSTDkAm
# bk_xmas1_StbgTGd2
# schub_d760_1_AkPnBcht
# mond_3_AkPnStgb
# mond_2_SptkBGCl
# bk_xmas5_StbgTGd2
# chpn_op7_2_SptkBGAm
# pathetique_1_ENSTDkCl
# ty_januar_AkPnStgb
# scn15_3_AkPnBcht
# ty_mai_ENSTDkCl
# ty_oktober_SptkBGAm
# bk_xmas5_AkPnCGdD
# br_im2_SptkBGAm
# chpn_op33_2_ENSTDkAm
# liz_et1_SptkBGAm
# scn15_6_ENSTDkAm
# appass_1_SptkBGCl
# deb_menu_StbgTGd2
# liz_et_trans4_SptkBGAm
# liz_rhap02_AkPnCGdD
# grieg_elfentanz_SptkBGAm
# alb_esp4_AkPnStgb
# scn15_12_ENSTDkCl
# chpn_op25_e4_ENSTDkAm
# deb_menu_ENSTDkCl
# chpn_op35_3_AkPnStgb
# waldstein_2_AkPnCGdD
# bk_xmas1_ENSTDkCl
# alb_esp6_SptkBGCl
# mond_1_SptkBGAm
# mz_570_1_ENSTDkCl
# mond_1_AkPnBsdf
# liz_et2_SptkBGAm
# chpn_op10_e05_SptkBGAm
# br_im2_AkPnCGdD
# mz_331_2_StbgTGd2
# schu_143_1_AkPnBcht
# liz_rhap09_StbgTGd2
# scn15_2_SptkBGCl
# pathetique_1_SptkBGCl
# grieg_wanderer_SptkBGAm
# alb_se4_AkPnBsdf
# bach_847_AkPnStgb
# ty_september_SptkBGAm
# alb_se3_AkPnBcht
# alb_se2_ENSTDkCl
# grieg_butterfly_ENSTDkCl
# liz_et_trans5_ENSTDkCl
# alb_se6_AkPnStgb
# deb_clai_StbgTGd2
# mz_311_1_StbgTGd2
# mz_333_2_ENSTDkCl
# grieg_butterfly_AkPnBsdf
# pathetique_2_ENSTDkAm
# alb_esp3_AkPnCGdD
# bach_847_AkPnBcht
# schub_d960_3_AkPnCGdD
# bach_847_SptkBGCl
# mz_331_2_AkPnBcht
# scn16_4_ENSTDkAm
# grieg_wanderer_AkPnBsdf
# burg_quelle_SptkBGAm
# ty_november_SptkBGCl
# bor_ps2_SptkBGAm
# alb_esp2_AkPnCGdD
# scn16_2_SptkBGCl
# liz_rhap09_ENSTDkCl
# ty_november_ENSTDkAm
# ty_maerz_ENSTDkCl
# alb_se2_StbgTGd2
# mz_331_2_AkPnBsdf
# schub_d760_3_ENSTDkAm
# bor_ps6_AkPnBsdf
# ty_mai_StbgTGd2
# chpn_op7_1_ENSTDkAm
# grieg_kobold_AkPnStgb
# bk_xmas3_AkPnStgb
# schub_d960_3_SptkBGCl
# mz_332_1_AkPnBsdf
# hay_40_1_AkPnBcht
# schu_143_1_ENSTDkAm
# scn15_12_StbgTGd2
# scn16_4_StbgTGd2
# mz_331_1_SptkBGCl
# grieg_waechter_AkPnBcht
# chpn_op25_e2_AkPnBcht
# deb_clai_ENSTDkCl
# gra_esp_4_AkPnBcht
# schumm
# ty_februar_SptkBGCl
# ty_juni_AkPnBsdf
# chpn_op66_AkPnBcht
# schuim
# br_im5_SptkBGCl
# burg_perlen_SptkBGCl
# grieg_walzer_SptkBGCl
# ty_juli_AkPnBcht
# grieg_walzer_AkPnBcht
# alb_esp5_SptkBGCl
# bk_xmas1_AkPnBsdf
# bach_846_SptkBGAm
# chpn_op10_e01_AkPnCGdD
# liz_et2_AkPnStgb
# alb_se3_AkPnBsdf
# schub_d960_3_AkPnStgb
# grieg_butterfly_ENSTDkAm
# scn16_4_SptkBGCl
# ty_maerz_StbgTGd2
# chpn_op35_1_ENSTDkAm
# appass_1_AkPnBsdf
# bach_846_AkPnBcht
# alb_esp2_SptkBGCl
# alb_esp2_AkPnStgb
# liz_rhap12_ENSTDkAm
# mendel_op62_5_ENSTDkAm
# mz_331_3_ENSTDkCl
# scn16_3_StbgTGd2
# schu_143_3_ENSTDkCl
# muss_5_AkPnBcht
# bk_xmas5_AkPnBcht
# mz_331_2_ENSTDkCl
# chpn_op33_4_SptkBGAm
# liz_rhap09_ENSTDkAm
# liz_et4_SptkBGCl
# liz_rhap09_SptkBGCl
# bach_850_AkPnBsdf
# grieg_butterfly_StbgTGd2
# liz_et5_AkPnCGdD
# waldstein_1_AkPnBsdf
# waldstein_3_SptkBGCl
# gra_esp_3_SptkBGAm
# muss_3_SptkBGCl

# %%
from collections import defaultdict
import re

def identify_pieces_by_instrument(files):
    """
    Identifies which pieces are played by which instruments using a single regex pattern.

    Args:
    - files: A list of file names (without extensions).

    Returns:
    - pieces_dict: A dictionary where keys are piece names and values are the instruments that play them.
    - unseen_pieces: A set of pieces that are unique to the training set (not repeated).
    - repeated_pieces: A set of pieces that are repeated across multiple instruments.
    """
    # Regex pattern to capture both piece name and instrument name
    pattern = re.compile(r'MAPS_MUS-(.*)_(\w+)')
    pieces_dict = defaultdict(set)

    for file_name in files:
        match = pattern.search(file_name)

        if match:
            piece_name = match.group(1)  # First capturing group for the piece name
            instrument_name = match.group(2)  # Second capturing group for the instrument name

            pieces_dict[piece_name].add(instrument_name)

    unseen_pieces = set()
    repeated_pieces = set()

    for piece, instruments in pieces_dict.items():
        if len(instruments) == 1:
            unseen_pieces.add(piece)
        else:
            repeated_pieces.add(piece)

    return pieces_dict, unseen_pieces, repeated_pieces

pieces_dict, unseen_pieces, repeated_pieces = identify_pieces_by_instrument(maps_files)

print(f"{len(repeated_pieces)} Repeated Pieces (Seen across multiple instruments): {repeated_pieces}")
print(f"{len(unseen_pieces)} Unseen Pieces (Unique to one instrument): {unseen_pieces}")
# Out:
# 70 Repeated Pieces (Seen across multiple instruments): {'mz_570_1', 'schumm-1', 'bk_xmas5', 'ty_november', 'chpn-p6', 'grieg_elfentanz', 'mz_331_3', 'alb_se2', 'mz_311_1', 'chpn-p7', 'deb_clai', 'bk_xmas1', 'chp_op31', 'scn15_11', 'mond_1', 'mz_331_2', 'chpn_op66', 'scn15_7', 'bk_xmas2', 'liz_et_trans5', 'grieg_walzer', 'liz_et2', 'schu_143_1', 'chpn-p14', 'br_im5', 'chpn_op25_e3', 'pathetique_1', 'ty_februar', 'ty_maerz', 'grieg_wanderer', 'waldstein_1', 'mendel_op62_5', 'scn16_3', 'deb_menu', 'appass_1', 'liz_rhap09', 'grieg_butterfly', 'chpn-p4', 'bor_ps6', 'chpn_op27_2', 'mz_545_3', 'chpn-p19', 'liz_rhap02', 'scn16_2', 'bach_846', 'ty_mai', 'ty_september', 'alb_esp2', 'alb_se3', 'bk_xmas4', 'chpn-e01', 'grieg_kobold', 'schuim-1', 'chpn-p13', 'mond_2', 'chpn_op33_2', 'scn16_4', 'mz_333_3', 'scn15_12', 'ty_juli', 'chpn-p15', 'mz_333_2', 'gra_esp_3', 'schub_d960_3', 'br_im2', 'chpn-p1', 'liz_et6', 'bach_847', 'schu_143_3', 'mz_332_2'}
# 90 Unseen Pieces (Unique to one instrument): {'scn15_9', 'waldstein_2', 'scn15_13', 'liz_et1', 'hay_40_1', 'alb_esp5', 'muss_4', 'bach_850', 'liz_et_trans4', 'mz_330_1', 'ty_juni', 'ty_dezember', 'bk_xmas3', 'grieg_zwerge', 'alb_se6', 'chpn_op35_3', 'chpn-p8', 'chpn-p16', 'chpn-p11', 'bor_ps1', 'chpn_op27_1', 'bor_ps2', 'schumm-3', 'chpn-p3', 'chpn-p12', 'schub_d760_3', 'gra_esp_4', 'muss_1', 'schumm-6', 'chp_op18', 'pathetique_2', 'grieg_halling', 'grieg_waechter', 'ty_januar', 'chpn-p24', 'mendel_op53_5', 'liz_et5', 'scn15_2', 'schuim-3', 'br_im6', 'chpn-p20', 'chpn-p9', 'gra_esp_2', 'chpn-p2', 'waldstein_3', 'schub_d760_1', 'mz_331_1', 'scn15_6', 'muss_2', 'liz_et4', 'ty_oktober', 'alb_esp3', 'chpn_op10_e12', 'burg_quelle', 'scn15_5', 'chpn_op25_e2', 'scn16_5', 'pathetique_3', 'chpn_op25_e4', 'chpn_op7_2', 'mz_332_1', 'liz_rhap12', 'chpn-p10', 'alb_se4', 'chpn-p21', 'bor_ps5', 'chpn_op33_4', 'deb_pass', 'appass_3', 'alb_esp6', 'chpn_op10_e05', 'chpn_op35_1', 'burg_perlen', 'alb_esp4', 'mos_op36_6', 'chpn-p11-format0', 'chpn_op7_1', 'muss_5', 'scn16_7', 'mond_3', 'muss_3', 'chpn_op10_e01', 'mz_333_1', 'schumm-2', 'scn15_3', 'liz_rhap10', 'alb_se8', 'liz_et3', 'schu_143_2', 'alb_se7'}

# %%
import re
from collections import defaultdict
import random

def split_dataset(files):
    """
    Splits the dataset into balanced train_tr, train_va, and test sets based on seen/unseen pieces
    and instrument categories.

    Args:
    - files: A list of file names (without extensions).

    Returns:
    - train_tr_files: A list of files for the training set.
    - train_va_files: A list of files for the validation set.
    - test_set1_files: A list of files for test set 1 (unseen real piano recordings).
    - test_set2_files: A list of files for test set 2 (both seen and unseen real piano recordings).
    """
    # Virtual instruments (for training)
    virtual_instruments = {'AkPnCGdD', 'AkPnStgb', 'AkPnBcht', 'AkPnBsdf', 'SptkBGCl', 'SptkBGAm', 'StbgTGd2'}

    # Real pianos (for testing)
    real_instruments = {'ENSTDkAm', 'ENSTDkCl'}

    # Regex pattern to extract piece name and instrument
    pattern = re.compile(r'MAPS_MUS-(.*)_(\w+)')

    # Dictionaries to store pieces by instrument
    pieces_dict = defaultdict(set)

    # Categorize pieces by instrument
    for file_name in files:
        match = pattern.search(file_name)
        if match:
            piece_name = match.group(1)
            instrument_name = match.group(2)
            pieces_dict[piece_name].add(instrument_name)

    # Split pieces into seen and unseen
    unseen_pieces = {piece for piece, instruments in pieces_dict.items() if len(instruments) == 1}
    seen_pieces = {piece for piece in pieces_dict if piece not in unseen_pieces}

    # Lists to store final file lists
    train_tr_files = []
    train_va_files = []
    test_set1_files = []
    test_set2_files = []

    # Step 1: Train (seen pieces from virtual instruments)
    for file_name in files:
        match = pattern.search(file_name)
        if match:
            piece_name = match.group(1)
            instrument_name = match.group(2)
            if instrument_name in virtual_instruments:
                if piece_name in seen_pieces:
                    train_tr_files.append(file_name)
                elif piece_name in unseen_pieces:
                    train_va_files.append(file_name)  # Validation will use unseen virtual pieces

    # Step 2: Test sets from real instruments
    for file_name in files:
        match = pattern.search(file_name)
        if match:
            piece_name = match.group(1)
            instrument_name = match.group(2)
            if instrument_name in real_instruments:
                if piece_name in unseen_pieces:
                    test_set1_files.append(file_name)  # Test Set 1: Unseen pieces
                test_set2_files.append(file_name)      # Test Set 2: Both seen and unseen pieces

    # Ensure validation set is balanced
    if len(train_va_files) > len(train_tr_files) * 0.2:  # Optional, if you want to limit validation size
        train_va_files = random.sample(train_va_files, int(len(train_tr_files) * 0.2))

    return train_tr_files, train_va_files, test_set1_files, test_set2_files

train_tr_files, train_va_files, test_set1_files, test_set2_files = split_dataset(file_list)

# Output the splits
print(f"Training Files: {len(train_tr_files)}")
print(f"Validation Files: {len(train_va_files)}")
print(f"Test Set 1 Files: {len(test_set1_files)}")
print(f"Test Set 2 Files: {len(test_set2_files)}")
# Out:
# Training Files: 130
# Validation Files: 26
# Test Set 1 Files: 10
# Test Set 2 Files: 60

# %%
import os
import shutil

def create_paper_split(audio_folder, text_folder, train_tr_files, train_va_files, test_set1_files, test_set2_files, output_dir):
    """
    Creates a 'paper_split' folder with subfolders for train_tr, train_va, test_set1, and test_set2.
    Copies the appropriate files from the audio and text folders into these subfolders.

    Args:
    - audio_folder: Path to the folder containing the original audio files.
    - text_folder: Path to the folder containing the original text files.
    - train_tr_files: List of files for the training set.
    - train_va_files: List of files for the validation set.
    - test_set1_files: List of files for test set 1.
    - test_set2_files: List of files for test set 2.
    - output_dir: Path to the output directory where the "paper_split" folder will be created.
    """

    # Define the subfolder structure for the paper split
    split_folders = {
        'train_tr': train_tr_files,
        'train_va': train_va_files,
        'test_set1': test_set1_files,
        'test_set2': test_set2_files
    }

    # Create the 'paper_split' folder
    paper_split_dir = os.path.join(output_dir, 'paper_split')
    os.makedirs(paper_split_dir, exist_ok=True)

    # Iterate over the splits and copy the files
    for split_name, file_list in split_folders.items():
        split_dir = os.path.join(paper_split_dir, split_name)
        os.makedirs(split_dir, exist_ok=True)

        for file_base in file_list:
            # Find the corresponding audio and text files
            audio_file = os.path.join(audio_folder, f"{file_base}.wav")
            text_file = os.path.join(text_folder, f"{file_base}.txt")

            # Copy audio and text files into the new subfolder
            if os.path.exists(audio_file):
                shutil.copy(audio_file, split_dir)
            if os.path.exists(text_file):
                shutil.copy(text_file, split_dir)

    print(f"Dataset has been split and copied into {paper_split_dir}.")

# Example usage
audio_folder = '/root/dev/data/audio'
text_folder = '/root/dev/data/text'
output_dir = '/root/dev/data/paper_split'

# Assuming train_tr_files, train_va_files, test_set1_files, test_set2_files are already generated from the split
create_paper_split(audio_folder, text_folder, train_tr_files, train_va_files, test_set1_files, test_set2_files, output_dir)
# Out:
# Dataset has been split and copied into /root/dev/data/paper_split/paper_split.
